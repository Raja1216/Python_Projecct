# %% [markdown]
# ### Singly Linked List
# #### 1. Define a Class Node to describe a node of a singly linked List
# #### 2. Define a Class SLL to implement Singly Linked List with __init__() method to create and initialize the start reference variable.
# #### 3. Define a method is_empty() to check if the linked list is empty in SLL Class.
# #### 4. In Class SLL define a method insert_at_start() to insert an element at the start of the list.
# #### 5. In Class SLL define a method insert_at_last() to insert an element at the end of the list.
# #### 6. In Class SLL define a method search() to find the node with the specific element value.
# #### 7. In Class SLL define a method insert_after() to insert a new node after a given node of the list.
# #### 8. In Class SLL define a method to print all the elements of the list.
# #### 9. In Class SLL implement an iterator for SLL to access all the elements of the list in a sequence.
# #### 10. In Class SLL define a method delete_first() to delete the first from the list.
# #### 11. In Class SLL define a method delete_last() to delete the last from the list.
# #### 12. In Class SLL define a method delete_item() to delete a specified element from the list.

# %%
class Node:
    def __init__(self,item=None,next=None):
        self.item = item
        self.next = next
class SLL:
    def __init__(self,start=None):
        self.start = start
    def is_empty(self):
        return self.start == None
    def insert_at_start(self,data):
        n = Node(data,self.start)
        self.start = n
    def insert_at_last(self,data):
        n = Node(data)
        if not self.is_empty():
            temp = self.start
            while temp.next is not None:
                temp = temp.next
            temp.next = n    
        else:
            self.start = n
    def search(self,data):
        temp = self.start
        while temp is not None:
            if temp.item == data:
                return temp
            temp = temp.next
        return None
    def insert_after(self,temp,data):
        if temp is not None:
             n = Node(data,temp.next)
             temp.next = n
    def print_elements(self):
        temp = self.start
        while temp is not None:
            print(temp.item, end=" ")
            temp = temp.next
    def delete_first(self):
        temp = self.start
        if temp is not None:
            self.start = temp.next
        
    def delete_last(self):
        temp = self.start
        prevTemp = self.start
        while temp.next is not None:
            prevTemp = temp
        prevTemp.next = None
        
    def delete_item(self,data):
        temp1 = self.start
        if temp1 in None:
            pass
        elif temp1.next is None and temp1.item == data:
            temp1 = None
        else:
            if temp1.item == data:
                temp1 = temp1.next
                
                
        
            
        



#driver Code
myList = SLL()
myList.insert_at_start(20)
myList.insert_at_last(50)
temp = myList.search(20)
myList.insert_after(temp,30)

myList.insert_at_start(10)
myList.insert_at_last(40)
temp = myList.search(10)
myList.insert_after(temp,70)

myList.print_elements()
# Out:
#   Cell In[11], line 51
#     def delete_item(self,temp):
#     ^
# IndentationError: expected an indented block after 'while' statement on line 46
